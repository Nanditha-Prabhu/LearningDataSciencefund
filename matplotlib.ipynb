# %% [markdown]
# MATPLOTLIB

# %%
#import numpy to generate random numbers
import numpy as np
import pandas as pd
#import matplotlib
import matplotlib.pyplot as plt
from matplotlib import style
# %matplotlib inline

# %%
#generate random numbers
randomNum = np.random.rand(10)

# %%
#view them
print(randomNum)
# Out:
# [0.79141838 0.79376917 0.2404327  0.35805883 0.22607807 0.60877644
#  0.58280345 0.41076618 0.98915433 0.14027059]

# %%
#select style of the plot
style.use('ggplot')
#plot random no
plt.plot(randomNum, 'b', label='first', linewidth=1) #data, color, legend, line-thickness
#x axis is number of random numbers
plt.xlabel('range')
#y axis is random number
plt.ylabel('numbers')
#title of plot
plt.title('GGPLOT')
#display
plt.legend()
plt.show()

# %%
#creating dataset
ingredients = 'laung', 'cardamom', 'elaichi', 'bay-leaf', 'turmeric', 'star-anise'
percentile = [75, 70, 60, 80, 95, 55]

# %%
#set size of img
plt.figure(figsize=(3, 3))
#explode largest pie of the chart
explode=(0, 0, 0, 0, 0.3, 0)
#plot it in pie chart
plt.pie(percentile, labels=ingredients, explode=explode, autopct='%1.1f%%', startangle=90)
#set title
plt.title('SPICES')
#display
plt.show()

# %% [markdown]
# working on house prices dataset

# %%
df = pd.read_csv('house_prices.csv', parse_dates=['date'], index_col=['date'] )
df.sort_index(inplace=True)
df.head()
# Out:
#                     id     price  bedrooms  bathrooms  sqft_living  sqft_lot
# date
# 2014-05-02  5561000190  437500.0         3       2.25         1970     35100  \
# 2014-05-02   472000620  790000.0         3       2.50         2600      4750
# 2014-05-02  1024069009  675000.0         5       2.50         2820     67518
# 2014-05-02  7853361370  555000.0         4       2.50         3310      6500
# 2014-05-02  5056500260  440000.0         4       2.25         2160      8119
#
#             floors  waterfront  view  condition  grade  sqft_above
# date
# 2014-05-02     2.0           0     0          4      9        1970  \
# 2014-05-02     1.0           0     0          4      9        1700
# 2014-05-02     2.0           0     0          3      8        2820
# 2014-05-02     2.0           0     0          3      8        3310
# 2014-05-02     1.0           0     0          3      8        1080
#
#             sqft_basement  yr_built  yr_renovated  zipcode      lat     long
# date
# ...

# %%
#line plot for the data
plt.plot(df['price'])

# %%
plt.figure(figsize= (10, 10), dpi = 100) #display pixels per inch-dpi
plt.xlabel('Time')
plt.ylabel('Price')
plt.title('Line plot of prices')
# plt.legend()
plt.plot(df['price'])
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
#box plot
plt.boxplot(df['price'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x225765d7c10>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x225724f4d90>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x225765f6fd0>],
#  'medians': [<matplotlib.lines.Line2D at 0x22576637750>],
#  'fliers': [<matplotlib.lines.Line2D at 0x22576614510>],
#  'means': []}

# %%
#histogram
plt.hist(df['bedrooms'])
# Out:
# (array([1.2796e+04, 8.7550e+03, 5.7000e+01, 4.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00]),
#  array([ 0. ,  3.3,  6.6,  9.9, 13.2, 16.5, 19.8, 23.1, 26.4, 29.7, 33. ]),
#  <BarContainer object of 10 artists>)

# %%
#scatterplot
plt.xlabel('price')
plt.ylabel('sqrt_living')
plt.title('Scatter plot for house prices')
plt.scatter(x=df['price'], y=df['sqft_living'])

# %% [markdown]
# 3d visualization

# %%
ax = plt.axes(projection = '3d')
int_price = df['price']
ax.scatter(df['price'], df['bedrooms'], df['grade'])
ax.set_xlabel('PRICE')
ax.set_ylabel('BEDROOMS')
ax.set_zlabel('GRADE')
plt.show()
